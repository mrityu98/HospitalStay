# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('./Dataset/LengthOfStay.csv')
pd.set_option('display.max_columns', None)
df.sample(10)
# Out:
#          eid       vdate rcount gender  dialysisrenalendstage  asthma  \
# 28972  28973   8/30/2012      0      M                      0       0
# 78413  78414   4/22/2012      3      M                      0       0
# 43456  43457  12/31/2012     5+      F                      0       0
# 66547  66548   5/27/2012      2      F                      0       0
# 93176  93177   10/1/2012      0      F                      0       0
# 50536  50537   8/23/2012      0      M                      0       0
# 64805  64806   5/17/2012      0      F                      0       0
# 91939  91940    8/6/2012      3      F                      0       0
# 12084  12085   2/24/2012      0      M                      0       0
# 16719  16720  11/16/2012      1      M                      0       0
#
#        irondef  pneum  substancedependence  psychologicaldisordermajor  \
# 28972        0      0                    0                           0
# 78413        0      0                    0                           0
# 43456        0      0                    0                           0
# 66547        0      0                    1                           0
# 93176        0      0                    0                           0
# 50536        0      0                    0                           1
# 64805        0      0                    0                           0
# 91939        0      0                    0                           0
# 12084        0      0                    0                           0
# 16719        0      0                    0                           0
#
#        depress  psychother  fibrosisandother  malnutrition  hemo  hematocrit  \
# 28972        0           0                 0             0     0        14.0
# 78413        0           0                 0             0     0        11.9
# 43456        0           0                 0             0     0         9.7
# 66547        0           0                 0             0     0         8.6
# 93176        0           0                 0             0     0        12.0
# 50536        0           0                 0             0     0        13.8
# 64805        0           0                 0             0     0        11.9
# 91939        0           0                 0             0     0        12.0
# 12084        0           1                 0             0     0        13.3
# 16719        0           0                 0             0     0        11.9
#
#        neutrophils      sodium     glucose  bloodureanitro  creatinine  \
# 28972          6.8  137.750392   73.211415            15.0    0.920132
# 78413          9.4  137.054573  175.539753            12.0    1.365436
# 43456          4.0  136.405379  127.701238            12.0    0.746308
# 66547         17.4  132.962478   96.250099            12.0    1.291535
# 93176          9.3  136.944556  197.315921            12.0    0.979611
# 50536         15.1  136.891523  159.023962             9.0    1.477463
# 64805          9.4  135.066873  156.430513            12.0    0.939270
# 91939          9.3  141.474903  142.983685            12.0    1.295880
# 12084          6.0  131.292318  159.064431            17.0    0.867394
# 16719          9.4  135.982994   95.908350            12.0    1.042161
#
#              bmi  pulse  respiration  secondarydiagnosisnonicd9  discharged  \
# 28972  25.051515     76          6.6                          1    9/1/2012
# 78413  29.665763     69          6.5                          1   4/27/2012
# 43456  32.193282     74          6.5                          1    1/9/2013
# 66547  32.314065     90          6.5                          1    6/6/2012
# 93176  31.740174     97          6.5                          0   10/3/2012
# 50536  30.245386     56          6.5                          3   8/27/2012
# 64805  27.250106     78          6.5                          3   5/18/2012
# 91939  29.704385     78          6.5                          7   8/11/2012
# 12084  29.033131     68          7.4                          1   2/29/2012
# 16719  30.324088     84          6.5                          0  11/18/2012
#
#       facid  lengthofstay
# 28972     A             2
# 78413     A             5
# 43456     A             9
# 66547     E            10
# 93176     B             2
# 50536     E             4
# 64805     A             1
# 91939     A             5
# 12084     E             5
# 16719     B             2

# %%
df.shape
# Out:
# (100000, 28)

# %%
from sklearn.model_selection import train_test_split
df_train,df_test=train_test_split(df,test_size=0.2,random_state=42)

# %%
df_train.shape
# Out:
# (80000, 28)

# %%
df_train.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 80000 entries, 75220 to 15795
# Data columns (total 28 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   eid                         80000 non-null  int64
#  1   vdate                       80000 non-null  object
#  2   rcount                      80000 non-null  object
#  3   gender                      80000 non-null  object
#  4   dialysisrenalendstage       80000 non-null  int64
#  5   asthma                      80000 non-null  int64
#  6   irondef                     80000 non-null  int64
#  7   pneum                       80000 non-null  int64
#  8   substancedependence         80000 non-null  int64
#  9   psychologicaldisordermajor  80000 non-null  int64
#  10  depress                     80000 non-null  int64
#  11  psychother                  80000 non-null  int64
#  12  fibrosisandother            80000 non-null  int64
#  13  malnutrition                80000 non-null  int64
#  14  hemo                        80000 non-null  int64
#  15  hematocrit                  80000 non-null  float64
#  16  neutrophils                 80000 non-null  float64
#  17  sodium                      80000 non-null  float64
#  18  glucose                     80000 non-null  float64
#  19  bloodureanitro              80000 non-null  float64
#  20  creatinine                  80000 non-null  float64
#  21  bmi                         80000 non-null  float64
#  22  pulse                       80000 non-null  int64
#  23  respiration                 80000 non-null  float64
#  24  secondarydiagnosisnonicd9   80000 non-null  int64
#  25  discharged                  80000 non-null  object
#  26  facid                       80000 non-null  object
#  27  lengthofstay                80000 non-null  int64
# dtypes: float64(8), int64(15), object(5)
# memory usage: 17.7+ MB

# %%
df_train.isnull().sum()
# Out:
# eid                           0
# vdate                         0
# rcount                        0
# gender                        0
# dialysisrenalendstage         0
# asthma                        0
# irondef                       0
# pneum                         0
# substancedependence           0
# psychologicaldisordermajor    0
# depress                       0
# psychother                    0
# fibrosisandother              0
# malnutrition                  0
# hemo                          0
# hematocrit                    0
# neutrophils                   0
# sodium                        0
# glucose                       0
# bloodureanitro                0
# creatinine                    0
# bmi                           0
# pulse                         0
# respiration                   0
# secondarydiagnosisnonicd9     0
# discharged                    0
# facid                         0
# lengthofstay                  0
# dtype: int64

# %%
df_train.describe()
# Out:
#                 eid  dialysisrenalendstage        asthma       irondef  \
# count  80000.000000           80000.000000  80000.000000  80000.000000
# mean   50022.926437               0.036312      0.034975      0.094750
# std    28869.648875               0.187068      0.183718      0.292871
# min        1.000000               0.000000      0.000000      0.000000
# 25%    25029.750000               0.000000      0.000000      0.000000
# 50%    50047.000000               0.000000      0.000000      0.000000
# 75%    75038.250000               0.000000      0.000000      0.000000
# max    99999.000000               1.000000      1.000000      1.000000
#
#               pneum  substancedependence  psychologicaldisordermajor  \
# count  80000.000000         80000.000000                80000.000000
# mean       0.039350             0.062350                    0.239325
# std        0.194427             0.241792                    0.426674
# min        0.000000             0.000000                    0.000000
# 25%        0.000000             0.000000                    0.000000
# 50%        0.000000             0.000000                    0.000000
# 75%        0.000000             0.000000                    0.000000
# max        1.000000             1.000000                    1.000000
#
#             depress    psychother  fibrosisandother  malnutrition  \
# count  80000.000000  80000.000000      80000.000000  80000.000000
# mean       0.052025      0.049212          0.004625      0.049337
# std        0.222079      0.216313          0.067850      0.216573
# min        0.000000      0.000000          0.000000      0.000000
# 25%        0.000000      0.000000          0.000000      0.000000
# 50%        0.000000      0.000000          0.000000      0.000000
# 75%        0.000000      0.000000          0.000000      0.000000
# max        1.000000      1.000000          1.000000      1.000000
#
#               hemo    hematocrit   neutrophils        sodium       glucose  \
# count  80000.00000  80000.000000  80000.000000  80000.000000  80000.000000
# mean       0.08045     11.979013     10.176926    137.885929    141.967963
# std        0.27199      2.035523      5.145802      3.000821     30.039815
# min        0.00000      4.400000      0.100000    125.259814     -1.005927
# 25%        0.00000     10.900000      7.700000    135.854702    121.657115
# 50%        0.00000     11.900000      9.400000    137.889114    142.086522
# 75%        0.00000     12.900000     11.500000    139.906375    162.216634
# max        1.00000     24.100000    245.900000    151.315937    271.444277
#
#        bloodureanitro    creatinine           bmi         pulse   respiration  \
# count    80000.000000  80000.000000  80000.000000  80000.000000  80000.000000
# mean        14.106032      1.099373     29.806527     73.456275      6.491869
# std         13.121823      0.200289      2.004944     11.661816      0.568923
# min          1.000000      0.219770     21.992683     21.000000      0.200000
# 25%         11.000000      0.964624     28.452336     66.000000      6.500000
# 50%         12.000000      1.098796     29.814477     73.000000      6.500000
# 75%         14.000000      1.234741     31.164777     81.000000      6.500000
# max        682.500000      2.035202     38.935293    126.000000     10.000000
#
#        secondarydiagnosisnonicd9  lengthofstay
# count               80000.000000  80000.000000
# mean                    2.118325      4.001762
# std                     2.047010      2.364747
# min                     0.000000      1.000000
# 25%                     1.000000      2.000000
# 50%                     1.000000      4.000000
# 75%                     3.000000      6.000000
# max                    10.000000     17.000000

# %%
df_train['lengthofstay'].value_counts()
# Out:
# lengthofstay
# 1     14416
# 3     12843
# 4     11795
# 2     10273
# 5      9674
# 6      8348
# 7      5765
# 8      3737
# 9      1753
# 10      800
# 11      371
# 12      111
# 13       61
# 14       29
# 15       15
# 16        6
# 17        3
# Name: count, dtype: int64

# %%
sb.histplot(df_train['lengthofstay'],bins=17,kde='True')
# Out:
# <Axes: xlabel='lengthofstay', ylabel='Count'>

# %%
print(f"The skewness of target column is {df_train['lengthofstay'].skew()} and kurtosis is {df_train['lengthofstay'].kurtosis()}")
# Out:
# The skewness of target column is 0.6343562697523857 and kurtosis is 8.752670622769188e-05

# %%
los_counts = df_train['lengthofstay'].value_counts().sort_index()

plt.figure(figsize=(8,6))
los_counts.plot(kind='barh')

plt.xlabel('Number of Patients')
plt.ylabel('Length of Stay (Days)')
plt.title('Distribution of Hospital Length of Stay')
# Out:
# Text(0.5, 1.0, 'Distribution of Hospital Length of Stay')

# %%
df_train['vdate']=pd.to_datetime(df_train['vdate'],format="%m/%d/%Y")
df_train['vdate'][:5]
# Out:
# 75220   2012-12-26
# 48955   2012-11-21
# 44966   2012-05-11
# 13568   2012-08-15
# 92727   2012-09-27
# Name: vdate, dtype: datetime64[ns]

# %%
df_train['year']=df_train['vdate'].dt.year
df_train['year'].value_counts()
# Out:
# year
# 2012    79796
# 2013      204
# Name: count, dtype: int64

# %%
df_train['month']=df_train['vdate'].dt.month
df_train['month'].value_counts()
# Out:
# month
# 10    6830
# 5     6829
# 1     6824
# 3     6796
# 8     6752
# 7     6688
# 12    6681
# 11    6656
# 9     6575
# 6     6547
# 2     6428
# 4     6394
# Name: count, dtype: int64

# %%
df_train.groupby('month')['lengthofstay'].mean()
# Out:
# month
# 1     4.006741
# 2     3.937306
# 3     4.027075
# 4     4.007194
# 5     4.041294
# 6     4.020467
# 7     4.000598
# 8     4.003555
# 9     4.004563
# 10    3.987555
# 11    4.001502
# 12    3.980392
# Name: lengthofstay, dtype: float64

# %%
df_train['quarter']=df_train['vdate'].dt.quarter
df_train['quarter'].value_counts()
# Out:
# quarter
# 4    20167
# 1    20048
# 3    20015
# 2    19770
# Name: count, dtype: int64

# %%
df_train.groupby('quarter')['lengthofstay'].mean()
# Out:
# quarter
# 1    3.991371
# 2    4.023369
# 3    4.002898
# 4    3.989785
# Name: lengthofstay, dtype: float64

# %%
df_train['discharged']=pd.to_datetime(df_train['discharged'],format="%m/%d/%Y")
df_train['discharged'][:5]
# Out:
# 75220   2012-12-31
# 48955   2012-11-28
# 44966   2012-05-17
# 13568   2012-08-20
# 92727   2012-10-03
# Name: discharged, dtype: datetime64[ns]

# %%
df_train['rcount'].value_counts()
# Out:
# rcount
# 0     44006
# 1     12063
# 2      7978
# 3      6414
# 4      5566
# 5+     3973
# Name: count, dtype: int64

# %%
df_train['rcount']=df_train['rcount'].replace("5+","5")
df_train['rcount']=df_train['rcount'].astype(int)

# %%
df_train['rcount'].value_counts()
# Out:
# rcount
# 0    44006
# 1    12063
# 2     7978
# 3     6414
# 4     5566
# 5     3973
# Name: count, dtype: int64

# %%
rcount_meanlos=df_train.groupby('rcount')['lengthofstay'].mean()
rcount_meanlos
# Out:
# rcount
# 0    2.720447
# 1    3.703473
# 2    5.278767
# 3    6.276115
# 4    7.254941
# 5    8.306066
# Name: lengthofstay, dtype: float64

# %%
sb.lineplot(data=rcount_meanlos,marker='o',dashes=True)
# Out:
# <Axes: xlabel='rcount', ylabel='lengthofstay'>

# %%
df_train['gender'].value_counts()
# Out:
# gender
# F    46042
# M    33958
# Name: count, dtype: int64

# %%
df_train.groupby('gender')['lengthofstay'].mean()
# Out:
# gender
# F    3.856892
# M    4.198186
# Name: lengthofstay, dtype: float64

# %%
df_train['facid'].value_counts()
# Out:
# facid
# E    24556
# B    24095
# A    24008
# C     3767
# D     3574
# Name: count, dtype: int64

# %%
df_train.groupby('facid')['lengthofstay'].mean()
# Out:
# facid
# A    3.272659
# B    3.288649
# C    4.902310
# D    4.802182
# E    5.159676
# Name: lengthofstay, dtype: float64

# %%
df_train.groupby('facid')['lengthofstay'].agg(['count','mean'])
# Out:
#        count      mean
# facid
# A      24008  3.272659
# B      24095  3.288649
# C       3767  4.902310
# D       3574  4.802182
# E      24556  5.159676

# %%
sb.histplot(df_train['pulse'],bins=15,kde='True')
# Out:
# <Axes: xlabel='pulse', ylabel='Count'>

# %%
print(f"The skewness of target column is {df_train['pulse'].skew()} and kurtosis is {df_train['pulse'].kurtosis()}")
# Out:
# The skewness of target column is 0.0015858735744729176 and kurtosis is 0.02207150597187013

# %%
los_meanpulse=df_train.groupby('lengthofstay')['pulse'].mean()
los_meanpulse
# Out:
# lengthofstay
# 1     73.404967
# 2     73.343425
# 3     73.468271
# 4     73.413396
# 5     73.337399
# 6     73.316603
# 7     73.453599
# 8     74.119079
# 9     73.911010
# 10    74.723750
# 11    74.501348
# 12    73.738739
# 13    74.672131
# 14    70.137931
# 15    69.466667
# 16    69.333333
# 17    67.333333
# Name: pulse, dtype: float64

# %%
sb.lineplot(data=los_meanpulse,marker='o',dashes=True)
# Out:
# <Axes: xlabel='lengthofstay', ylabel='pulse'>

# %%
df_train['secondarydiagnosisnonicd9'].value_counts().sort_index()
# Out:
# secondarydiagnosisnonicd9
# 0      8093
# 1     40065
# 2      7879
# 3      7163
# 4      7154
# 5      3205
# 6      2479
# 7      1531
# 8       786
# 9       816
# 10      829
# Name: count, dtype: int64

# %%
sb.kdeplot(data=df_train,x='hematocrit',fill=True,color='orange')
# Out:
# <Axes: xlabel='hematocrit', ylabel='Density'>

# %%
print(f"The skewness of target column is {df_train['hematocrit'].skew()} and kurtosis is {df_train['hematocrit'].kurtosis()}")
# Out:
# The skewness of target column is 0.5669205756256738 and kurtosis is 1.837769415761056

# %%
df_train.groupby('lengthofstay')['hematocrit'].agg(['count','mean'])
# Out:
#               count       mean
# lengthofstay
# 1             14416  11.997333
# 2             10273  12.126280
# 3             12843  12.153316
# 4             11795  12.048278
# 5              9674  11.850357
# 6              8348  11.851140
# 7              5765  11.887479
# 8              3737  11.884863
# 9              1753  11.666931
# 10              800  11.443146
# 11              371  11.129856
# 12              111  10.513514
# 13               61  10.629508
# 14               29  10.672759
# 15               15   9.580000
# 16                6   8.866667
# 17                3   7.783333

# %%
sb.boxplot(data=df_train,x='hematocrit',orient='h')
# Out:
# <Axes: xlabel='hematocrit'>

# %%
sb.kdeplot(data=df_train,x='neutrophils',fill=True,color='green')
# Out:
# <Axes: xlabel='neutrophils', ylabel='Density'>

# %%
print(f"The skewness of target column is {df_train['neutrophils'].skew()} and kurtosis is {df_train['neutrophils'].kurtosis()}")
# Out:
# The skewness of target column is 11.776888353309277 and kurtosis is 376.82479623780273

# %%
df_train.groupby('lengthofstay')['neutrophils'].agg(['count','mean'])
# Out:
#               count       mean
# lengthofstay
# 1             14416  10.199510
# 2             10273  10.706340
# 3             12843  10.148865
# 4             11795  10.023285
# 5              9674   9.835459
# 6              8348  10.062106
# 7              5765  10.281397
# 8              3737  10.125069
# 9              1753  10.221634
# 10              800  10.123667
# 11              371  10.434070
# 12              111  11.457958
# 13               61   9.031967
# 14               29  10.334138
# 15               15   8.620000
# 16                6   6.433333
# 17                3  43.333333

# %%
sb.boxplot(data=df_train,x='neutrophils',orient='h')
# Out:
# <Axes: xlabel='neutrophils'>

# %%
sb.kdeplot(data=df_train,x='sodium',fill=True,color='black')
# Out:
# <Axes: xlabel='sodium', ylabel='Density'>

# %%
print(f"The skewness of target column is {df_train['sodium'].skew()} and kurtosis is {df_train['sodium'].kurtosis()}")
# Out:
# The skewness of target column is 0.006109558794971963 and kurtosis is 0.007931981872051352

# %%
sb.boxplot(data=df_train,x='sodium',orient='h')
# Out:
# <Axes: xlabel='sodium'>

# %%
sb.kdeplot(data=df_train,x='glucose',fill=True,color='blue')
# Out:
# <Axes: xlabel='glucose', ylabel='Density'>

# %%
print(f"The skewness of target column is {df_train['glucose'].skew()} and kurtosis is {df_train['glucose'].kurtosis()}")
# Out:
# The skewness of target column is -0.013231620763942412 and kurtosis is 0.01117713041580437

# %%
sb.boxplot(data=df_train,x='glucose',orient='h')
# Out:
# <Axes: xlabel='glucose'>

# %%
(df_train['glucose'] < 0).sum()
# Out:
# np.int64(1)

# %%
df_train.groupby('lengthofstay')['glucose'].mean()
# Out:
# lengthofstay
# 1     141.912557
# 2     141.921647
# 3     142.184306
# 4     141.969929
# 5     141.769309
# 6     142.103644
# 7     142.494612
# 8     142.294423
# 9     140.687209
# 10    141.302726
# 11    137.814132
# 12    140.754077
# 13    141.088175
# 14    137.574856
# 15    132.688016
# 16    130.161401
# 17     92.004112
# Name: glucose, dtype: float64

# %%
df_train.groupby(
    pd.qcut(df_train['glucose'], q=4)
)['lengthofstay'].mean()
# Out:
# C:\Users\mrmkc\AppData\Local\Temp\ipykernel_20756\1143395058.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_train.groupby(
# glucose
# (-1.007, 121.657]     4.19875
# (121.657, 142.087]    3.80005
# (142.087, 162.217]    3.82300
# (162.217, 271.444]    4.18525
# Name: lengthofstay, dtype: float64

# %%
sb.kdeplot(data=df_train,x='bloodureanitro',fill=True,color='purple')
# Out:
# <Axes: xlabel='bloodureanitro', ylabel='Density'>

# %%
print(f"The skewness of target column is {df_train['bloodureanitro'].skew()} and kurtosis is {df_train['bloodureanitro'].kurtosis()}")
# Out:
# The skewness of target column is 17.76634791892565 and kurtosis is 555.0405024329717

# %%
sb.boxplot(data=df_train,x='bloodureanitro',orient='h')
# Out:
# <Axes: xlabel='bloodureanitro'>

# %%
df_train.groupby('lengthofstay')['bloodureanitro'].mean()
# Out:
# lengthofstay
# 1     11.950830
# 2     12.076651
# 3     13.408374
# 4     14.267536
# 5     15.062794
# 6     15.666457
# 7     15.673036
# 8     15.899166
# 9     18.500285
# 10    21.039917
# 11    24.601752
# 12    28.735736
# 13    30.631148
# 14    34.344828
# 15    37.000000
# 16    39.833333
# 17    45.666667
# Name: bloodureanitro, dtype: float64

# %%
df_train.groupby(
    pd.qcut(df_train['bloodureanitro'], q=4)
)['lengthofstay'].mean()
# Out:
# C:\Users\mrmkc\AppData\Local\Temp\ipykernel_20756\659278532.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_train.groupby(
# bloodureanitro
# (0.999, 11.0]    4.182977
# (11.0, 12.0]     3.401808
# (12.0, 14.0]     4.428492
# (14.0, 682.5]    4.897202
# Name: lengthofstay, dtype: float64

# %%
df_train.groupby(
    pd.qcut(df_train['bloodureanitro'], q=10, duplicates='drop')
)['lengthofstay'].mean()
# Out:
# C:\Users\mrmkc\AppData\Local\Temp\ipykernel_20756\2420615027.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_train.groupby(
# bloodureanitro
# (0.999, 8.0]     4.154833
# (8.0, 10.0]      4.220329
# (10.0, 12.0]     3.463931
# (12.0, 15.0]     4.433928
# (15.0, 21.0]     4.498870
# (21.0, 682.5]    5.461930
# Name: lengthofstay, dtype: float64

# %%
sb.kdeplot(data=df_train,x='creatinine',fill=True,color='darkgreen',alpha=0.6)
# Out:
# <Axes: xlabel='creatinine', ylabel='Density'>

# %%
print(f"The skewness of target column is {df_train['creatinine'].skew()} and kurtosis is {df_train['creatinine'].kurtosis()}")
# Out:
# The skewness of target column is 0.004834685101740761 and kurtosis is 0.0032629058844722003

# %%
sb.boxplot(data=df_train,x='creatinine',orient='h')
# Out:
# <Axes: xlabel='creatinine'>

# %%
df_train.groupby('lengthofstay')['creatinine'].mean()
# Out:
# lengthofstay
# 1     1.098926
# 2     1.100198
# 3     1.101093
# 4     1.101426
# 5     1.097655
# 6     1.099678
# 7     1.095482
# 8     1.097940
# 9     1.096119
# 10    1.099483
# 11    1.109734
# 12    1.058178
# 13    1.041201
# 14    1.198525
# 15    1.098826
# 16    1.213828
# 17    1.055392
# Name: creatinine, dtype: float64

# %%
df_train.groupby(
    pd.qcut(df_train['creatinine'], q=4)
)['lengthofstay'].mean()
# Out:
# C:\Users\mrmkc\AppData\Local\Temp\ipykernel_20756\775292138.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_train.groupby(
# creatinine
# (0.219, 0.965]    4.20690
# (0.965, 1.099]    3.81360
# (1.099, 1.235]    3.81660
# (1.235, 2.035]    4.16995
# Name: lengthofstay, dtype: float64

# %%
df_train.groupby(
    pd.qcut(df_train['creatinine'], q=10, duplicates='drop')
)['lengthofstay'].mean()
# Out:
# C:\Users\mrmkc\AppData\Local\Temp\ipykernel_20756\4014923653.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_train.groupby(
# creatinine
# (0.219, 0.843]    4.570875
# (0.843, 0.931]    4.043875
# (0.931, 0.995]    3.805500
# (0.995, 1.048]    3.823250
# (1.048, 1.099]    3.807750
# (1.099, 1.15]     3.783625
# (1.15, 1.204]     3.784875
# (1.204, 1.267]    3.863000
# (1.267, 1.356]    3.986375
# (1.356, 2.035]    4.548500
# Name: lengthofstay, dtype: float64

# %%
sb.kdeplot(data=df_train,x='bmi',fill=True,color='darkred',alpha=0.3)
# Out:
# <Axes: xlabel='bmi', ylabel='Density'>

# %%
print(f"The skewness of target column is {df_train['bmi'].skew()} and kurtosis is {df_train['bmi'].kurtosis()}")
# Out:
# The skewness of target column is 0.0038444406647345206 and kurtosis is -0.007310650147658304

# %%
df_train.groupby('lengthofstay')['bmi'].mean()
# Out:
# lengthofstay
# 1     29.813496
# 2     29.779838
# 3     29.830222
# 4     29.799142
# 5     29.841129
# 6     29.783181
# 7     29.840750
# 8     29.769700
# 9     29.696727
# 10    29.733107
# 11    29.895267
# 12    29.443473
# 13    30.090580
# 14    30.222632
# 15    29.433046
# 16    29.146203
# 17    28.386775
# Name: bmi, dtype: float64

# %%
sb.boxplot(data=df_train,x='bmi',orient='h')
# Out:
# <Axes: xlabel='bmi'>

# %%
sb.kdeplot(data=df_train,x='pulse',fill=True,color='yellow',alpha=0.4)
# Out:
# <Axes: xlabel='pulse', ylabel='Density'>

# %%
print(f"The skewness of target column is {df_train['pulse'].skew()} and kurtosis is {df_train['pulse'].kurtosis()}")
# Out:
# The skewness of target column is 0.0015858735744729176 and kurtosis is 0.02207150597187013

# %%
df_train.groupby(
    pd.qcut(df_train['pulse'], q=4)
)['lengthofstay'].mean()
# Out:
# C:\Users\mrmkc\AppData\Local\Temp\ipykernel_20756\1965871529.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_train.groupby(
# pulse
# (20.999, 66.0]    4.118213
# (66.0, 73.0]      3.810172
# (73.0, 81.0]      3.843522
# (81.0, 126.0]     4.212891
# Name: lengthofstay, dtype: float64

# %%
sb.boxplot(data=df_train,x='pulse',orient='h')
# Out:
# <Axes: xlabel='pulse'>

# %%
sb.kdeplot(data=df_train,x='respiration',fill=True,color='pink',alpha=0.7)
# Out:
# <Axes: xlabel='respiration', ylabel='Density'>

# %%
print(f"The skewness of target column is {df_train['respiration'].skew()} and kurtosis is {df_train['respiration'].kurtosis()}")
# Out:
# The skewness of target column is -0.584773054018199 and kurtosis is 8.378610067131385

# %%
df_train.groupby('lengthofstay')['respiration'].mean()
# Out:
# lengthofstay
# 1     6.497006
# 2     6.489093
# 3     6.502140
# 4     6.512948
# 5     6.501150
# 6     6.482263
# 7     6.478974
# 8     6.479598
# 9     6.424786
# 10    6.398500
# 11    6.336815
# 12    6.149099
# 13    6.230055
# 14    6.265517
# 15    6.546667
# 16    5.833333
# 17    5.833333
# Name: respiration, dtype: float64

# %%
sb.boxplot(data=df_train,x='respiration',orient='h')
# Out:
# <Axes: xlabel='respiration'>

# %%
bin_cols=['dialysisrenalendstage','asthma','irondef','pneum','substancedependence','psychologicaldisordermajor','depress','psychother','fibrosisandother','malnutrition','hemo']

# %%
df_train['comorbidity_count'] = df_train[bin_cols].sum(axis=1)
df_train.columns
# Out:
# Index(['eid', 'vdate', 'rcount', 'gender', 'dialysisrenalendstage', 'asthma',
#        'irondef', 'pneum', 'substancedependence', 'psychologicaldisordermajor',
#        'depress', 'psychother', 'fibrosisandother', 'malnutrition', 'hemo',
#        'hematocrit', 'neutrophils', 'sodium', 'glucose', 'bloodureanitro',
#        'creatinine', 'bmi', 'pulse', 'respiration',
#        'secondarydiagnosisnonicd9', 'discharged', 'facid', 'lengthofstay',
#        'year', 'month', 'quarter', 'comorbidity_count'],
#       dtype='object')

# %%
df_train.groupby('comorbidity_count')['lengthofstay'].mean()
# Out:
# comorbidity_count
# 0    3.108181
# 1    4.986414
# 2    5.157570
# 3    5.298316
# 4    6.738186
# 5    6.956452
# 6    7.328638
# 7    8.102564
# 8    9.545455
# 9    9.333333
# Name: lengthofstay, dtype: float64

# %%
df_train['has_any_condition'] = (df_train['comorbidity_count'] > 0).astype(int)

# %%
df_train.groupby('has_any_condition')['lengthofstay'].mean()
# Out:
# has_any_condition
# 0    3.108181
# 1    5.203147
# Name: lengthofstay, dtype: float64

# %%
df_train['flag_psych_cluster'] = (
    (df_train['psychologicaldisordermajor'] == 1) |
    (df_train['depress'] == 1) |
    (df_train['psychother'] == 1) |
    (df_train['substancedependence'] == 1)
).astype(int)

# %%
df_train.groupby('flag_psych_cluster')['lengthofstay'].mean()
# Out:
# flag_psych_cluster
# 0    3.440398
# 1    5.237266
# Name: lengthofstay, dtype: float64

# %%
df_train['flag_hematological'] = (
    (df_train['hemo'] == 1) |
    (df_train['irondef'] == 1)
).astype(int)

# %%
df_train.groupby('flag_hematological')['lengthofstay'].mean()
# Out:
# flag_hematological
# 0    3.722359
# 1    5.496349
# Name: lengthofstay, dtype: float64

# %%
df_train['flag_respiratory'] = (
    (df_train['pneum'] == 1) |
    (df_train['asthma'] == 1) |
    (df_train['fibrosisandother'] == 1)
).astype(int)

# %%
df_train.groupby('flag_respiratory')['lengthofstay'].mean()
# Out:
# flag_respiratory
# 0    3.892860
# 1    5.348538
# Name: lengthofstay, dtype: float64

# %%
df_train['flag_metabolic_risk'] = (
    (df_train['malnutrition'] == 1) |
    (df_train['dialysisrenalendstage'] == 1)
).astype(int)

# %%
df_train.groupby('flag_metabolic_risk')['lengthofstay'].mean()
# Out:
# flag_metabolic_risk
# 0    3.854721
# 1    5.802616
# Name: lengthofstay, dtype: float64

# %%
df_train['flag_low_hematocrit']  = (df_train['hematocrit'] < 36).astype(int)       # anaemia threshold
df_train['flag_low_sodium']      = (df_train['sodium'] < 135).astype(int)           # hyponatremia
df_train['flag_high_glucose']    = (df_train['glucose'] > 180).astype(int)          # hyperglycemia
df_train['flag_high_creatinine'] = (df_train['creatinine'] > 1.2).astype(int)       # renal stress
df_train['flag_high_bun']        = (df_train['bloodureanitro'] > 20).astype(int)    # elevated BUN
df_train['flag_obese']           = (df_train['bmi'] > 30).astype(int)               # obesity
df_train['flag_tachycardia']     = (df_train['pulse'] > 100).astype(int)

# %%
lab_flags = ['flag_low_hematocrit','flag_low_sodium','flag_high_glucose',
             'flag_high_creatinine','flag_high_bun','flag_obese','flag_tachycardia']

# %%
for col in lab_flags:
    print(df_train.groupby(col)['lengthofstay'].mean())
# Out:
# flag_low_hematocrit
# 1    4.001762
# Name: lengthofstay, dtype: float64
# flag_low_sodium
# 0    3.914685
# 1    4.432736
# Name: lengthofstay, dtype: float64
# flag_high_glucose
# 0    3.937261
# 1    4.566931
# Name: lengthofstay, dtype: float64
# flag_high_creatinine
# 0    3.947734
# 1    4.123364
# Name: lengthofstay, dtype: float64
# flag_high_bun
# 0    3.842735
# 1    5.360534
# Name: lengthofstay, dtype: float64
# flag_obese
# 0    4.000974
# 1    4.002683
# Name: lengthofstay, dtype: float64
# flag_tachycardia
# 0    3.994191
# 1    4.733822
# Name: lengthofstay, dtype: float64

# %%
df_train['abnormal_lab_count'] = df_train[lab_flags].sum(axis=1)
df_train.groupby('abnormal_lab_count')['lengthofstay'].mean()
# Out:
# abnormal_lab_count
# 1    3.635637
# 2    3.876183
# 3    4.298323
# 4    4.899509
# 5    5.708861
# 6    7.074074
# Name: lengthofstay, dtype: float64

# %%
datetime_cols=['vdate','discharged']
cat_cols=['rcount','gender','facid','comorbidity_count','abnormal_lab_count']
bin_cols=['dialysisrenalendstage','asthma','irondef','pneum','substancedependence','psychologicaldisordermajor','depress','psychother','fibrosisandother','malnutrition','hemo','has_any_condition','flag_psych_cluster','flag_hematological','flag_respiratory','flag_metabolic_risk'] + lab_flags
num_cols=['hematocrit','neutrophils','sodium','glucose','bloodureanitro','creatinine','bmi','pulse','respiration','lengthofstay']

# %%
for col in cat_cols:
    df_train[col]=df_train[col].astype("category")

# %%
corr_cols = num_cols + bin_cols 

pearson_corr = df_train[corr_cols].corr(method='pearson')

plt.figure(figsize=(18,10))
sb.heatmap(
    pearson_corr,
    annot=True,
    fmt=".2f",
    cmap='coolwarm',
    center=0
)
plt.title("Pearson Correlation Heatmap")
plt.tight_layout()
plt.savefig('./Images/pearson_corr.png',dpi=300)
plt.show()

# %%
spearman_corr = df_train[corr_cols].corr(method='spearman')

plt.figure(figsize=(20,10))
sb.heatmap(
    spearman_corr,
    annot=True,
    fmt=".2f",
    cmap='viridis',
    center=0
)
plt.title("Spearman Correlation Heatmap")
plt.tight_layout()
plt.savefig('./Images/spearman_corr.png',dpi=300)
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
for col in ['gender', 'facid']:
    df_train[f'{col}_le'] = LabelEncoder().fit_transform(df_train[col])

# %%
feature_cols = (
    num_cols +
    bin_cols +
    cat_cols
)
feature_cols.remove('gender')
feature_cols.remove('facid') 
feature_cols.remove('lengthofstay') 
feature_cols.append('gender_le') 
feature_cols.append('facid_le') 
X_mi = df_train[feature_cols].copy()
y_mi = df_train['lengthofstay']

# %%
feature_cols
# Out:
# ['hematocrit',
#  'neutrophils',
#  'sodium',
#  'glucose',
#  'bloodureanitro',
#  'creatinine',
#  'bmi',
#  'pulse',
#  'respiration',
#  'dialysisrenalendstage',
#  'asthma',
#  'irondef',
#  'pneum',
#  'substancedependence',
#  'psychologicaldisordermajor',
#  'depress',
#  'psychother',
#  'fibrosisandother',
#  'malnutrition',
#  'hemo',
#  'has_any_condition',
#  'flag_psych_cluster',
#  'flag_hematological',
#  'flag_respiratory',
#  'flag_metabolic_risk',
#  'flag_low_hematocrit',
#  'flag_low_sodium',
#  'flag_high_glucose',
#  'flag_high_creatinine',
#  'flag_high_bun',
#  'flag_obese',
#  'flag_tachycardia',
#  'rcount',
#  'comorbidity_count',
#  'abnormal_lab_count',
#  'gender_le',
#  'facid_le']

# %%
from sklearn.feature_selection import mutual_info_regression

mi_scores = mutual_info_regression(
    X_mi,
    y_mi,
    random_state=42
)

mi_df = pd.DataFrame({
    'Feature': X_mi.columns,
    'MI_Score': mi_scores
})

mi_df = mi_df.sort_values(
    by='MI_Score',
    ascending=False
)

mi_df
# Out:
#                        Feature  MI_Score
# 32                      rcount  0.506216
# 33           comorbidity_count  0.244697
# 20           has_any_condition  0.227067
# 36                    facid_le  0.151246
# 21          flag_psych_cluster  0.150158
# 14  psychologicaldisordermajor  0.103173
# 22          flag_hematological  0.065588
# 4               bloodureanitro  0.058772
# 0                   hematocrit  0.053949
# 8                  respiration  0.048039
# 1                  neutrophils  0.046369
# 11                     irondef  0.042308
# 24         flag_metabolic_risk  0.039400
# 19                        hemo  0.036072
# 23            flag_respiratory  0.028743
# 15                     depress  0.025367
# 13         substancedependence  0.024619
# 16                  psychother  0.020664
# 18                malnutrition  0.020365
# 29               flag_high_bun  0.019121
# 9        dialysisrenalendstage  0.018562
# 12                       pneum  0.017383
# 34          abnormal_lab_count  0.014144
# 6                          bmi  0.013152
# 2                       sodium  0.012435
# 10                      asthma  0.012055
# 7                        pulse  0.011248
# 5                   creatinine  0.011155
# 3                      glucose  0.010496
# 26             flag_low_sodium  0.008626
# 27           flag_high_glucose  0.003436
# 17            fibrosisandother  0.001694
# 25         flag_low_hematocrit  0.000937
# 35                   gender_le  0.000208
# 28        flag_high_creatinine  0.000000
# 31            flag_tachycardia  0.000000
# 30                  flag_obese  0.000000

# %%
plt.figure(figsize=(16,14))

sb.barplot(
    data=mi_df,
    x='MI_Score',
    y='Feature'
)

plt.title('Mutual Information Scores')
plt.xlabel('MI Score')
plt.ylabel('Feature')

plt.tight_layout()

# Save as PNG
plt.savefig(
    './Images/mutual_information_scores.png',
    dpi=300,
    bbox_inches='tight'
)

plt.show()

# %%
cramers_cols = bin_cols + ['gender', 'facid']

# %%
from scipy.stats import chi2_contingency

def cramers_v(x, y):
    confusion_matrix = pd.crosstab(x, y)

    chi2 = chi2_contingency(confusion_matrix)[0]
    n = confusion_matrix.sum().sum()

    phi2 = chi2 / n

    r, k = confusion_matrix.shape

    phi2corr = max(
        0,
        phi2 - ((k - 1) * (r - 1)) / (n - 1)
    )

    rcorr = r - ((r - 1) ** 2) / (n - 1)
    kcorr = k - ((k - 1) ** 2) / (n - 1)

    return np.sqrt(
        phi2corr / max(1, min(kcorr - 1, rcorr - 1))
    )

# %%
cramers_matrix = pd.DataFrame(
    np.zeros((len(cramers_cols), len(cramers_cols))),
    index=cramers_cols,
    columns=cramers_cols
)

for col1 in cramers_cols:
    for col2 in cramers_cols:
        cramers_matrix.loc[col1, col2] = cramers_v(
            df_train[col1],
            df_train[col2]
        )

# %%
plt.figure(figsize=(16, 12))

sb.heatmap(
    cramers_matrix,
    annot=True,
    fmt=".2f",
    cmap="YlGnBu",
    vmin=0,
    vmax=1
)

plt.title(
    "Cramer's V Association Heatmap",
    fontsize=16
)
plt.savefig('./Images/cramersV.png',dpi=300)
plt.tight_layout()
